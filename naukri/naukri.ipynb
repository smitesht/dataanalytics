# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv(r'./data/naukri_com-job_sample.csv')
df.head()
# Out:
#                                       company  \
# 0                            MM Media Pvt Ltd
# 1                          find live infotech
# 2         Softtech Career Infosystem Pvt. Ltd
# 3                      Onboard HRServices LLP
# 4  Spire Technologies and Solutions Pvt. Ltd.
#
#                                            education   experience  \
# 0  UG: B.Tech/B.E. - Any Specialization PG:Any Po...    0 - 1 yrs
# 1  UG: B.Tech/B.E. - Any Specialization PG:MBA/PG...    0 - 0 yrs
# 2  UG: Any Graduate - Any Specialization PG:Any P...    4 - 8 yrs
# 3  UG: Any Graduate - Any Specialization PG:CA Do...  11 - 15 yrs
# 4  UG: B.Tech/B.E. - Any Specialization PG:Any Po...    6 - 8 yrs
#
#                                    industry  \
# 0          Media / Entertainment / Internet
# 1  Advertising / PR / MR / Event Management
# 2           IT-Software / Software Services
# 3    Banking / Financial Services / Broking
# 4           IT-Software / Software Services
#
# ...

# %%
# list all columns
df.columns
# Out:
# Index(['company', 'education', 'experience', 'industry', 'jobdescription',
#        'jobid', 'joblocation_address', 'jobtitle', 'numberofpositions',
#        'payrate', 'postdate', 'site_name', 'skills', 'uniq_id'],
#       dtype='object')

# %%
# how many rows and columns
df.shape
# Out:
# (22000, 14)

# %%
# check missing values
df.isnull().sum()
# Out:
# company                    4
# education               1996
# experience                 4
# industry                   5
# jobdescription             4
# jobid                      0
# joblocation_address      501
# jobtitle                   0
# numberofpositions      17536
# payrate                   97
# postdate                  23
# site_name              18013
# skills                   528
# uniq_id                    0
# dtype: int64

# %%
# count how many percentage are missing values for each columns
count_missing = df.isnull().sum()
percent_missing = cnt_missing = (count_missing / len(df)) * 100
percent_missing
# Out:
# company                 0.018182
# education               9.072727
# experience              0.018182
# industry                0.022727
# jobdescription          0.018182
# jobid                   0.000000
# joblocation_address     2.277273
# jobtitle                0.000000
# numberofpositions      79.709091
# payrate                 0.440909
# postdate                0.104545
# site_name              81.877273
# skills                  2.400000
# uniq_id                 0.000000
# dtype: float64

# %%
missing_val_df = pd.DataFrame({'count_missing':count_missing, 'percent_missing':percent_missing})
missing_val_df
# Out:
#                      count_missing  percent_missing
# company                          4         0.018182
# education                     1996         9.072727
# experience                       4         0.018182
# industry                         5         0.022727
# jobdescription                   4         0.018182
# jobid                            0         0.000000
# joblocation_address            501         2.277273
# jobtitle                         0         0.000000
# numberofpositions            17536        79.709091
# payrate                         97         0.440909
# postdate                        23         0.104545
# site_name                    18013        81.877273
# skills                         528         2.400000
# uniq_id                          0         0.000000

# %%
# Highlight higher percentage and missing count
missing_val_df.style.background_gradient()
# Out:
# <style type="text/css">
# #T_6d8b1_row0_col0, #T_6d8b1_row0_col1, #T_6d8b1_row2_col0, #T_6d8b1_row2_col1, #T_6d8b1_row3_col0, #T_6d8b1_row3_col1, #T_6d8b1_row4_col0, #T_6d8b1_row4_col1, #T_6d8b1_row5_col0, #T_6d8b1_row5_col1, #T_6d8b1_row7_col0, #T_6d8b1_row7_col1, #T_6d8b1_row10_col0, #T_6d8b1_row10_col1, #T_6d8b1_row13_col0, #T_6d8b1_row13_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_6d8b1_row1_col0, #T_6d8b1_row1_col1 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_6d8b1_row6_col0, #T_6d8b1_row6_col1, #T_6d8b1_row12_col0, #T_6d8b1_row12_col1 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_6d8b1_row8_col0, #T_6d8b1_row8_col1 {
#   background-color: #023e62;
#   color: #f1f1f1;
# }
# #T_6d8b1_row9_col0, #T_6d8b1_row9_col1 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_6d8b1_row11_col0, #T_6d8b1_row11_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6d8b1">
#   <thead>
#     <tr>
# ...

# %% [markdown]
# ### list unique and total number of unique values from each of the column

# %%
#  list all the columns
df.columns
# Out:
# Index(['company', 'education', 'experience', 'industry', 'jobdescription',
#        'jobid', 'joblocation_address', 'jobtitle', 'numberofpositions',
#        'payrate', 'postdate', 'site_name', 'skills', 'uniq_id'],
#       dtype='object')

# %%
# make list of all the unique counts and values from each of the column one by one
# Method 1
unique_df = [ [col, df[col].nunique(), df[col].unique()] for col in df.columns]

# Method 2  
# unique_df = []
#for col in df.columns:
#    unique.append([col ,df[col].nunique(),df[col].unique()])
    
unique
# Out:
# [['company',
#   8469,
#   array(['MM Media Pvt Ltd', 'find live infotech',
#          'Softtech Career Infosystem Pvt. Ltd', ...,
#          'TeamLease Services Limited hiring for BPA Solution Architect',
#          'Austere Technology Solutions', 'Musk - Startup'], dtype=object)],
#  ['education',
#   2355,
#   array(['UG: B.Tech/B.E. - Any Specialization PG:Any Postgraduate - Any Specialization, Post Graduation Not Required',
#          'UG: B.Tech/B.E. - Any Specialization PG:MBA/PGDM - Any Specialization',
#          'UG: Any Graduate - Any Specialization PG:Any Postgraduate Doctorate:Doctorate Not Required',
#          ..., 'PG:MS/M.Sc(Science) - Any Specialization, Statistics',
#          'UG: B.Tech/B.E. - Any Specialization PG:MCA - Computers, M.Tech - Any Specialization, MS/M.Sc(Science) - Any Specialization Doctorate:Doctorate Not Required',
#          'UG: B.Tech/B.E. - Computers PG:MS/M.Sc(Science) - Computers Doctorate:Doctorate Not Required'],
# ...

# %%
pd.DataFrame(unique)
